# %%
import jupytext

# 读取带 # %% 的 .py 文件
nb1 = jupytext.read("stage1_experiment.py")

# 保存为 .ipynb
jupytext.write(nb1, "stage1_experiment.ipynb", fmt=".ipynb")


# 读取带 # %% 的 .py 文件
nb2 = jupytext.read("stage2_analysis.py")

# 保存为 .ipynb
jupytext.write(nb2, "stage2_analysis.ipynb", fmt=".ipynb")
